# %% [markdown]
# <a href="https://colab.research.google.com/github/Khushie-Jaiswal/DermaScan/blob/main/gradcam_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Section 1: Install dependencies (torch already installed on Colab)
Section 2: Load a pretrained ResNet18
Section 3: Load a test image
Section 4: Run Grad-CAM
Section 5: Display heatmap overlay
# Out:
#   File "/tmp/ipython-input-1576435034.py", line 1
#     Section 1: Install dependencies (torch already installed on Colab)
#             ^
# SyntaxError: invalid syntax
