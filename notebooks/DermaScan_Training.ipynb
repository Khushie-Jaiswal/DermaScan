# %% [markdown]
# <a href="https://colab.research.google.com/github/Khushie-Jaiswal/DermaScan/blob/main/notebooks/DermaScan_Training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')

# !pip install torch torchvision opencv-python pillow matplotlib numpy tqdm ttach
# Out:
# Mounted at /content/drive
# ...
